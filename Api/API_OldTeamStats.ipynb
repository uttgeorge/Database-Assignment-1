# %%
########### Python 3.2 #############
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '116a7c5b926d4da68f65094be64015f9',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/nba/stats/JSON/TeamSeasonStats/2018?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

####################################
# Out:
# b'[{"StatID":401658,"TeamID":3,"SeasonType":1,"Season":2018,"Name":"Atlanta Hawks","Team":"ATL","Wins":24,"Losses":58,"OpponentPosition":null,"Possessions":9048.2,"GlobalTeamID":20000003,"Updated":"2018-06-24T20:19:33","Games":82,"FantasyPoints":18316.1,"Minutes":22206,"Seconds":64,"FieldGoalsMade":3527.5,"FieldGoalsAttempted":7903.7,"FieldGoalsPercentage":50.3,"EffectiveFieldGoalsPercentage":57.7,"TwoPointersMade":2494.1,"TwoPointersAttempted":5036.6,"TwoPointersPercentage":55.8,"ThreePointersMade":1033.5,"ThreePointersAttempted":2867.1,"ThreePointersPercentage":40.6,"FreeThrowsMade":1462.8,"FreeThrowsAttempted":1864.1,"FreeThrowsPercentage":88.5,"OffensiveRebounds":836.2,"DefensiveRebounds":3032.8,"Rebounds":3869.0,"OffensiveReboundsPercentage":null,"DefensiveReboundsPercentage":null,"TotalReboundsPercentage":null,"Assists":2192.0,"Steals":719.0,"BlockedShots":392.2,"Turnovers":1388.5,"PersonalFouls":1810.0,"Points":9551.3,"TrueShootingAttempts":8723.8,"TrueShootingPercentage":61.6
# ...

# %%
import pandas as pd
import json
df = json.loads(data)
df=pd.DataFrame(df)
df.to_csv('OldTeamStats.csv',index=False)
